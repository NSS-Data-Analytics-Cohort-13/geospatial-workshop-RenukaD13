# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
streams = gpd.read_file('../data/Perennial_Streams.geojson')
print(streams.crs)
streams.head( )
# Out:
# EPSG:4326
#    OBJECTID    HYDROID  FTYPE    FCODE           NAME       DIG_NAME DRAIN  \
# 0         1  100000002  RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 1         2  100000004  RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 2         3  100000005  RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 3         4  100000006  RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 4         5  100000007  RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
#
#    RCHID VISIBLE SOURCE  SHAPE_Length  \
# 0    0.0       Y             0.000094
# 1    0.0       Y             0.000063
# 2    0.0       Y             0.000870
# 3    0.0       Y             0.000613
# 4    0.0       Y             0.000571
#
#                                             geometry
# 0  MULTILINESTRING ((-77.32547 39.06566, -77.3254...
# 1  MULTILINESTRING ((-77.32563 39.0655, -77.32562...
# 2  MULTILINESTRING ((-77.32495 39.06541, -77.3250...
# 3  MULTILINESTRING ((-77.32458 39.06537, -77.3246...
# ...

# %%
type(streams)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#streams.loc[1, 'geometry']
streams.loc[3, 'geometry']
# Out:
# <MULTILINESTRING ((-77.325 39.065, -77.325 39.065, -77.325 39.065, -77.325 3...>

# %%
streams
# Out:
#        OBJECTID    HYDROID    FTYPE    FCODE           NAME       DIG_NAME  \
# 0             1  100000002    RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 1             2  100000004    RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 2             3  100000005    RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 3             4  100000006    RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# 4             5  100000007    RIVER  46010.0  POTOMAC RIVER  POTOMAC RIVER
# ...         ...        ...      ...      ...            ...            ...
# 19514     21410   28200470   STREAM  46011.0           None       strm8287
# 19515     21411   28200326   STREAM  46011.0           None       strm7961
# 19516     21412         -1  SSN_ARC      NaN           None           None
# 19517     21413         -1   STREAM      NaN           None           None
# 19518     21414         -1   STREAM      NaN           None           None
#
#       DRAIN       RCHID VISIBLE SOURCE  SHAPE_Length  \
# ...

# %%
streams.plot();

# %%
#geopandas will take care of legend styling if you pass a dict of keywords

leg_kwds = {'title': 'Streams', 'bbox_to_anchor': (1, 1.03), 'ncol': 3}

streams.plot(column = 'FCODE', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 #geopandas will take care of legend styling if you pass a dict of keywords
#       3 leg_kwds = {'title': 'Streams', 'bbox_to_anchor': (1, 1.03), 'ncol': 3}
# ----> 5 streams.plot(column = 'FCODE', figsize=(10, 10),
#       6               edgecolor = 'black',
#       7               legend = True, legend_kwds = leg_kwds,
#       8               cmap = 'Set2')
#       9 plt.show()
#
# File C:\LaptopUsers\Renuka\Data Analytics bootcamp 2024\Python\Anaconda\envs\geospatial\lib\site-packages\geopandas\plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
# ...
